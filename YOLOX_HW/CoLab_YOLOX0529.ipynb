# %%
# !git clone https://github.com/Megvii-BaseDetection/YOLOX.git
# Out:
# Cloning into 'YOLOX'...
# remote: Enumerating objects: 1665, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 1665 (delta 1), reused 2 (delta 0), pack-reused 1656
# Receiving objects: 100% (1665/1665), 6.03 MiB | 24.11 MiB/s, done.
# Resolving deltas: 100% (973/973), done.

# %%
# !pip install -r YOLOX/requirements.txt

# %%
# !pip install cython

# %%
# !pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
import gdown
# !pip install --upgrade --no-cache-dir gdown

#download the yolox_s weights
url='https://drive.google.com/uc?id=1Uts1BB4lKtao9Rehz7xdZzZvUNVnd7Qf'
output='yolox_s.zip'

gdown.download(url=url,output=output,quiet=False,fuzzy=True)
# !unzip yolox_s.zip

#move yolox.pth to YOLOX folder
# !mv yolox_s.pth YOLOX

# %%
#PASCAL VOC label format 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#PASCAL VOC label format 
from zipfile import ZipFile
with ZipFile("drive/MyDrive/202205/VOC.zip","r") as ZipObj:
  ZipObj.extractall("YOLOX/datasets")
# url='https://drive.google.com/uc?id=1PqPCh_fb_a2Kflkjd5qdqXZtDn83FubP'
# output='VOC.zip'

# gdown.download(url=url,output=output,quiet=False,fuzzy=True)
# !unzip VOC.zip

# #move it to YOLOX/datasets
# !mv VOCdevkit YOLOX/datasets

# %% [markdown]
# # testing image
# # test資料集 在 YOLOX/datasets/VOCdevkit/VOC2007/test

# %%
#split label folder to PASCAL VOC format 

url='https://drive.google.com/uc?id=1PjMqsnXY1gURm9xHqh3mFmyLo-bKNk7b'
output='split_voc.py'

gdown.download(url=url,output=output,quiet=False,fuzzy=True)

#move it to YOLOX
# !mv split_voc.py YOLOX
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PjMqsnXY1gURm9xHqh3mFmyLo-bKNk7b
# To: /content/split_voc.py
# 100%|██████████| 1.04k/1.04k [00:00<00:00, 268kB/s]

# %%
# %cd /content/YOLOX
# !python split_voc.py
# Out:
# /content/YOLOX

# %%
# !python tools/train.py -f exps/example/yolox_voc/yolox_voc_s.py -d 1 -b 16 --fp16 -o -c yolox_s.pth
# Out:
# 2022-05-29 03:07:09 | INFO     | yolox.core.trainer:130 - args: Namespace(batch_size=16, cache=False, ckpt='yolox_s.pth', devices=1, dist_backend='nccl', dist_url=None, exp_file='exps/example/yolox_voc/yolox_voc_s.py', experiment_name='yolox_voc_s', fp16=True, logger='tensorboard', machine_rank=0, name=None, num_machines=1, occupy=True, opts=[], resume=False, start_epoch=None)
# 2022-05-29 03:07:09 | INFO     | yolox.core.trainer:131 - exp value:
# ╒═══════════════════╤════════════════════════════╕
# │ keys              │ values                     │
# ╞═══════════════════╪════════════════════════════╡
# │ seed              │ None                       │
# ├───────────────────┼────────────────────────────┤
# │ output_dir        │ './YOLOX_outputs'          │
# ├───────────────────┼────────────────────────────┤
# │ print_interval    │ 10                         │
# ├───────────────────┼────────────────────────────┤
# │ eval_interval     │ 10                         │
# ...

# %%
#image testing

# !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_s.py -c YOLOX_outputs/yolox_voc_s/best_ckpt.pth --path testfiles/6774.jpg --conf 0.3 --nms 0.65 --tsize 640 --save_result --device gpu
# Out:
# 2022-05-29 03:23:36.176 | INFO     | __main__:main:260 - Args: Namespace(camid=0, ckpt='YOLOX_outputs/yolox_voc_s/best_ckpt.pth', conf=0.3, demo='image', device='gpu', exp_file='exps/example/yolox_voc/yolox_voc_s.py', experiment_name='yolox_voc_s', fp16=False, fuse=False, legacy=False, name=None, nms=0.65, path='testfiles/6774.jpg', save_result=True, trt=False, tsize=640)
# 2022-05-29 03:23:36.372 | INFO     | __main__:main:270 - Model Summary: Params: 8.94M, Gflops: 26.64
# 2022-05-29 03:23:40.238 | INFO     | __main__:main:283 - loading checkpoint
# 2022-05-29 03:23:40.350 | INFO     | __main__:main:287 - loaded checkpoint done.
# 2022-05-29 03:23:40.443 | INFO     | __main__:inference:166 - Infer time: 0.0656s
# 2022-05-29 03:23:40.455 | INFO     | __main__:image_demo:203 - Saving detection result in ./YOLOX_outputs/yolox_voc_s/vis_res/2022_05_29_03_23_40/6774.jpg

# %%
#image testing (batch)

# !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_s.py -c YOLOX_outputs/yolox_voc_s/best_ckpt.pth --path testfiles --conf 0.3 --nms 0.65 --tsize 640 --save_result --device gpu
# Out:
# 2022-05-29 03:37:14.362 | INFO     | __main__:main:260 - Args: Namespace(camid=0, ckpt='YOLOX_outputs/yolox_voc_s/best_ckpt.pth', conf=0.3, demo='image', device='gpu', exp_file='exps/example/yolox_voc/yolox_voc_s.py', experiment_name='yolox_voc_s', fp16=False, fuse=False, legacy=False, name=None, nms=0.65, path='testfiles', save_result=True, trt=False, tsize=640)
# 2022-05-29 03:37:14.581 | INFO     | __main__:main:270 - Model Summary: Params: 8.94M, Gflops: 26.64
# 2022-05-29 03:37:18.610 | INFO     | __main__:main:283 - loading checkpoint
# 2022-05-29 03:37:18.723 | INFO     | __main__:main:287 - loaded checkpoint done.
# 2022-05-29 03:37:18.796 | INFO     | __main__:inference:166 - Infer time: 0.0647s
# 2022-05-29 03:37:18.797 | INFO     | __main__:image_demo:203 - Saving detection result in ./YOLOX_outputs/yolox_voc_s/vis_res/2022_05_29_03_37_18/6774.jpg
# 2022-05-29 03:37:18.823 | INFO     | __main__:inference:166 - Infer time: 0.0186s
# ...
